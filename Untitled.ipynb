# %%
from keras.models import Sequential
from keras.layers import Convolution2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Out:
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# initialize cnn
classifier = Sequential()

# step 1 convolution
classifier.add(Convolution2D(32, 3, 3, input_shape = (64, 64, 3), activation = 'relu'))

# step 2 Pooling
classifier.add(MaxPooling2D(pool_size = (2,2)))

# step 3 flattening
classifier.add(Flatten())
# Out:
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(64, 64, 3..., activation="relu")`
#   """

# %%
# step 4 full connection
classifier.add(Dense(output_dim = 128, activation = 'relu'))
classifier.add(Dense(output_dim = 1, activation = 'sigmoid'))

# compiling the cnn
classifier.compile(optimizer = 'adam', loss= 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="relu", units=128)`
#
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(activation="sigmoid", units=1)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from keras.preprocessing.image import ImageDataGenerator 
train_datagen = ImageDataGenerator(
  rescale = 1./255,
    shear_range = 0.2,
    zoom_range= 0.2,
    horizontal_flip = True
  )

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(
    '\dataset\test',
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary'  
)

test_set = test_datagen.flow_from_directory(
    '\dataset\train',
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary'
)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-a994d882c5d3> in <module>()
#      13     target_size = (64, 64),
#      14     batch_size = 32,
# ---> 15     class_mode = 'binary'
#      16 )
#      17
#
# ~\Anaconda3\lib\site-packages\keras_preprocessing\image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation)
#    1011             follow_links=follow_links,
#    1012             subset=subset,
# -> 1013             interpolation=interpolation)
#    1014
#    1015     def flow_from_dataframe(self, dataframe, directory,
#
# ...

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\dynamic_h\Desktop\exercise file\grocery

# %%
from IPython.display import display
from PIL import Image

classifier.fit_generator(
    training_set,
    steps_per_epoch = 80,
    epochs = 10,
    validation_data = test_set,
    validation_steps = 80
)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 34s 427ms/step - loss: -1.4965 - acc: 0.5973 - val_loss: -0.5709 - val_acc: 0.5359
# Epoch 2/10
# 80/80 [==============================] - 29s 360ms/step - loss: -1.6538 - acc: 0.5953 - val_loss: -0.7204 - val_acc: 0.6163
# Epoch 3/10
# 80/80 [==============================] - 26s 329ms/step - loss: -1.6538 - acc: 0.5980 - val_loss: -0.3609 - val_acc: 0.4237
# Epoch 4/10
# 80/80 [==============================] - 26s 326ms/step - loss: -1.8655 - acc: 0.5875 - val_loss: -0.7508 - val_acc: 0.6116
# Epoch 5/10
# 80/80 [==============================] - 28s 355ms/step - loss: -1.8565 - acc: 0.6160 - val_loss: -0.2590 - val_acc: 0.6367
# Epoch 6/10
# 80/80 [==============================] - 27s 333ms/step - loss: -1.8543 - acc: 0.6109 - val_loss: -0.7702 - val_acc: 0.5641
# Epoch 7/10
# 80/80 [==============================] - 30s 372ms/step - loss: -2.0331 - acc: 0.6340 - val_loss: -0.9363 - val_acc: 0.5736
# Epoch 8/10
# ...

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /home/harshit/Desktop/workflow/grocery

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('/home/harshit/Desktop/workflow/grocery/dataset/test/Fruit/Apple/Granny-Smith/Granny-Smith_001.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
training_set.class_indices

if result[0][0] >= 0.5:
    prediction = '1'
    
else:
    prediction = '2'
    
print(prediction)
# Out:
# 2

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD, RMSprop, adam

# %%
from keras.utils import np_utils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import os
import theano
from PIL import Image
from numpy import *

from sklearn.utils import shuffle
from sklearn.cross_validation import train_test_split
# Out:
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\dynamic_h\Desktop\exercise file\grocery

# %%
path1 = cwd  + "\dataset\input_folder"
print(path1)
path2 = cwd +  "\dataset\input_folder_resize"
print(path2)
# Out:
# C:\Users\dynamic_h\Desktop\exercise file\grocery\dataset\input_folder
# C:\Users\dynamic_h\Desktop\exercise file\grocery\dataset\input_folder_resize

# %%
listing = os.listdir(path1)
num_samples=size(listing)
print(num_samples)
# Out:
# 2530

# %%
img_rows, img_cols = 200, 200
for file in listing:
    im = Image.open(path1 + '\\' + file)
    img = im.resize((img_rows, img_cols))
    gray = img.convert('L')
    gray.save(path2 + '\\' + file, "jpeg")

# %%
imlist = os.listdir(path2)
print(len(imlist))
# Out:
# 2530

# %%
im1 = array(Image.open('dataset\input_folder_resize' + '\\' + imlist[0]))
m,n = im1.shape[0:2]
imnbr = len(imlist)

# %%
immatrix = array([array(Image.open('dataset\input_folder_resize'+'\\'+im2)).flatten()
                  for im2 in imlist],'f')

# %%
immatrix.shape
# Out:
# (2530, 40000)

# %%
label = np.ones((num_samples,),dtype = int)

# %%
len(label)
imlist
# Out:
# ['fruit00000.jpg',
#  'fruit00001.jpg',
#  'fruit00002.jpg',
#  'fruit00003.jpg',
#  'fruit00004.jpg',
#  'fruit00005.jpg',
#  'fruit00006.jpg',
#  'fruit00007.jpg',
#  'fruit00008.jpg',
#  'fruit00009.jpg',
#  'fruit00010.jpg',
#  'fruit00011.jpg',
#  'fruit00012.jpg',
#  'fruit00013.jpg',
#  'fruit00014.jpg',
#  'fruit00015.jpg',
#  'fruit00016.jpg',
#  'fruit00017.jpg',
#  'fruit00018.jpg',
#  'fruit00019.jpg',
#  'fruit00020.jpg',
#  'fruit00021.jpg',
#  'fruit00022.jpg',
#  'fruit00023.jpg',
#  'fruit00024.jpg',
#  'fruit00025.jpg',
#  'fruit00026.jpg',
#  'fruit00027.jpg',
#  'fruit00028.jpg',
#  'fruit00029.jpg',
#  'fruit00030.jpg',
#  'fruit00031.jpg',
#  'fruit00032.jpg',
#  'fruit00033.jpg',
#  'fruit00034.jpg',
#  'fruit00035.jpg',
#  'fruit00036.jpg',
#  'fruit00037.jpg',
#  'fruit00038.jpg',
#  'fruit00039.jpg',
#  'fruit00040.jpg',
#  'fruit00041.jpg',
#  'fruit00042.jpg',
#  'fruit00043.jpg',
#  'fruit00044.jpg',
#  'fruit00045.jpg',
#  'fruit00046.jpg',
# ...

# %%
label[0:1161] = 0
label[1162:1942] = 1
label[1943:] = 2

# %%
data, Label = shuffle(immatrix, label, random_state=1)
train_data = [data, Label]

# %%
img = immatrix[1943].reshape(img_rows,img_cols)
plt.imshow(img)
plt.imshow(img,cmap='gray')
print(train_data[0].shape)
print(train_data[1].shape)
# Out:
# (2530, 40000)
# (2530,)

# %%
batch_size  = 32
nb_classes = 3
nb_epoch = 4 

img_rows, img_cols = 200, 200

img_channels = 1 
nb_filters = 32
nb_pool = 2 
nb_conv = 3

# %%
(X, y) = (train_data[0], train_data[1])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=4)

# %%
X_train = X_train.reshape(X_train.shape[0],img_cols, img_rows,1)
X_test = X_test.reshape(X_test.shape[0], img_cols , img_rows,1)

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (2024, 200, 200, 1)
# 2024 train samples
# 506 test samples

# %%
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

# %%
i = 100
plt.imshow(X_train[i, 0], interpolation='nearest')
print("label :", Y_train[i,:])
# Out:
# label : [1. 0. 0.]

# %%
model = Sequential()

model.add(Convolution2D(nb_filters, nb_conv, nb_conv, 
                       border_mode='valid',
                       input_shape=(img_cols, img_rows, 1 )))
convout1 = Activation("relu")
model.add(convout1)
model.add(Convolution2D(nb_filters ,nb_conv, nb_conv))
convout2 = Activation('relu')
model.add(convout2)
model.add(MaxPooling2D(pool_size=(nb_pool, nb_pool)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(nb_classes))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer= 'adadelta')
# Out:
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(200, 200,..., padding="valid")`
#   """
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3))`

# %%
model.fit(X_train, Y_train, batch_size=batch_size, nb_epoch=nb_epoch,
verbose=1, validation_data=(X_test, Y_test))
# Out:
# C:\Users\dynamic_h\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 2024 samples, validate on 506 samples
# Epoch 1/4
# 2024/2024 [==============================] - 440s 217ms/step - loss: 1.0659 - val_loss: 1.0547
# Epoch 2/4
# 2024/2024 [==============================] - 484s 239ms/step - loss: 1.0724 - val_loss: 1.0533
# Epoch 3/4
# 2024/2024 [==============================] - 456s 225ms/step - loss: 1.0684 - val_loss: 1.0634
# Epoch 4/4
# 2024/2024 [==============================] - 440s 217ms/step - loss: 1.0697 - val_loss: 1.0554

# %%
score = model.evaluate(X_test, Y_test, metrics=['accuracy'], verbose = 0)
print('Test score:', score[0])
print('Test accuracy', score[1])
print(model.predict_classes(X_test[1:5]))
print(Y_test[1:5])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-df8489d32f40> in <module>()
# ----> 1 score = model.evaluate(X_test, Y_test, metrics=['accuracy'], verbose = 0)
#       2 print('Test score:', score[0])
#       3 print('Test accuracy', score[1])
#       4 print(model.predict_classes(X_test[1:5]))
#       5 print(Y_test[1:5])
#
# TypeError: evaluate() got an unexpected keyword argument 'metrics'
